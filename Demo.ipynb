# %%
from BRSAScore import SAScorer
from IPython.display import display, SVG

scorer = SAScorer()

# %%
drugs = {
    'Cularine': 'CN1CCC2=C3[C@@H]1CC4=CC(=C(C=C4OC3=C(C=C2)OC)OC)OC',
    'Goniomitine': 'CC[C@]12CCCN[C@H]1N3C(=C(C4=CC=CC=C43)CCO)CC2',
    'Fusaequisin A': 'CCCCC(C)C=CC=C(C)[C@@H]1[C@H]([C@@H]([C@H](O1)OC)C=C(C)C=CC(C(C)C(=O)C)OC)C',
    'Haliclonin A': 'C1CCCCCN(CC[C@@H]2[C@@H]3C[C@@]/4(CCCC1)CN(C3=O)CCC/C=C\C/C=C\C[C@H](/C=C4/C2=O)O)C=O', 
    'Hyacinthacine A1': 'C1C[C@@H]2[C@@H]([C@@H]([C@H](N2C1)CO)O)O',
    'Hydroxyancepsenolide': 'C[C@H]1C=C(C(=O)O1)CCCCCCCCCCCC[C@H]2[C@H]([C@@H](OC2=O)C)O',
    'Kirkamide': 'CC(=O)N[C@H]1[C@H](C=C([C@H]([C@@H]1O)O)CO)O',
    'Longianone': 'C1C(=O)OCC12C(=O)C=CO2',
    'Simpotentin': 'CCCCCC(CC(CC(=O)O)O[C@H]1[C@H]([C@H]([C@@H]([C@H](O1)CO)O)O)O)OC(=O)CC(CC(CCC)O)O',
    'Halomon': 'CC(C)([C@@H](CC[C@@](CBr)(C(=C)Cl)Cl)Br)Cl',
    'Dihydropinidine': 'CCCC1CCCC(N1)C',
    'Scorodonin': 'C(C=C=CC#CCCl)O',
    'Pinnatolide': 'CC(=CC(=O)CC1(CCC(=O)O1)C)C',
    'Tanikolide': 'CCCCCCCCCCC[C@@]1(CCCC(=O)O1)CO',
    'Sedridine': 'C[C@@H](C[C@@H]1CCCCN1)O',
    'Isolaurepan': 'CCCCCC[C@H]1CCCC[C@@H](CCC)O1',
    'cis-Perhydroazulene': 'C1CC[C@@H]2CCC[C@@H]2CC1',
    'Gabapentin': 'C1CCC(CC1)(CC(=O)O)CN',
}

for drug, smi in drugs.items():
    score, contribution = scorer.calculateScore(smi)
    svg = scorer.contribution_to_svg(smi, contribution)
    display(SVG(svg))
    print ('%s (%s)' % (smi, drug))
    print ('R2Score: %.3f' % score)
# Out:
# CN1CCC2=C3[C@@H]1CC4=CC(=C(C=C4OC3=C(C=C2)OC)OC)OC (Cularine)
# R2Score: 0.420
# CC[C@]12CCCN[C@H]1N3C(=C(C4=CC=CC=C43)CCO)CC2 (Goniomitine)
# R2Score: 0.272
# CCCCC(C)C=CC=C(C)[C@@H]1[C@H]([C@@H]([C@H](O1)OC)C=C(C)C=CC(C(C)C(=O)C)OC)C (Fusaequisin A)
# R2Score: 0.145
# C1CCCCCN(CC[C@@H]2[C@@H]3C[C@@]/4(CCCC1)CN(C3=O)CCC/C=C\C/C=C\C[C@H](/C=C4/C2=O)O)C=O (Haliclonin A)
# R2Score: 0.000
# C1C[C@@H]2[C@@H]([C@@H]([C@H](N2C1)CO)O)O (Hyacinthacine A1)
# R2Score: 0.394
# C[C@H]1C=C(C(=O)O1)CCCCCCCCCCCC[C@H]2[C@H]([C@@H](OC2=O)C)O (Hydroxyancepsenolide)
# R2Score: 0.204
# CC(=O)N[C@H]1[C@H](C=C([C@H]([C@@H]1O)O)CO)O (Kirkamide)
# R2Score: 0.238
# C1C(=O)OCC12C(=O)C=CO2 (Longianone)
# R2Score: 0.347
# CCCCCC(CC(CC(=O)O)O[C@H]1[C@H]([C@H]([C@@H]([C@H](O1)CO)O)O)O)OC(=O)CC(CC(CCC)O)O (Simpotentin)
# R2Score: 0.444
# CC(C)([C@@H](CC[C@@](CBr)(C(=C)Cl)Cl)Br)Cl (Halomon)
# R2Score: 0.045
# CCCC1CCCC(N1)C (Dihydropinidine)
# R2Score: 0.710
# C(C=C=CC#CCCl)O (Scorodonin)
# R2Score: 0.216
# ...
